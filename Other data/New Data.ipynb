# %%
import json

# %%
with open('Other data from Chinese Website/listofCountry.json','r') as f:
    kkk=f.read()

# %%
apnaData=json.loads(kkk)

# %%
len(apnaData['data'])
# Out:
# 169

# %%
apnaData
# Out:
# {'data': [{'id': 1305684,
#    'createTime': 1584608328000,
#    'modifyTime': 1584608328000,
#    'tags': '',
#    'countryType': 2,
#    'continents': '??',
#    'provinceId': '10',
#    'provinceName': '???',
#    'provinceShortName': '',
#    'cityName': '',
#    'currentConfirmedCount': 28710,
#    'confirmedCount': 35713,
#    'suspectedCount': 0,
#    'curedCount': 4025,
#    'deadCount': 2978,
#    'comment': '',
#    'sort': 0,
#    'operator': 'hejiashu',
#    'locationId': 965008,
#    'countryShortCode': 'ITA',
#    'countryFullName': 'Italy',
#    'statisticsData': 'https://file1.dxycdn.com/2020/0315/993/3402160517102843054-135.json'},
#   {'id': 1305686,
#    'createTime': 1584608328000,
#    'modifyTime': 1584608328000,
#    'tags': '',
#    'countryType': 2,
#    'continents': '??',
#    'provinceId': '10',
#    'provinceName': '???',
#    'provinceShortName': '',
#    'cityName': '',
#    'currentConfirmedCount': 12037,
#    'confirmedCount': 13716,
# ...
